# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from config import weather_api_key


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/my_cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
weather_data = pd.DataFrame({"City": cities})

# %%
weather_data['Latitude'] = ""
weather_data['Longitude'] = ""
weather_data['Max Temperature'] = ""
weather_data['Humidity'] = ""
weather_data['Cloudiness'] = ""
weather_data['Wind Speed'] = ""
weather_data['Country'] = ""
weather_data['Date'] = ""

# %%
print(f"Beginning Data Retrieval")
print(f"-----------------------------")

city_counter = 1

for index, row in weather_data.iterrows():
    url = "http://api.openweathermap.org/data/2.5/weather?"
    units = "imperial"
    query_url = f"{url}appid={weather_api_key}&units={units}&q="
    city = row['City']
    response = requests.get(query_url + city).json()
  
    print(f"Processing Record {city_counter} of Set 1 | {city}")
    city_counter += 1    
    
    try:
        weather_data.loc[index, "Latitude"] = response['coord']['lat']
        weather_data.loc[index, "Longitude"] = response['coord']['lon']
        weather_data.loc[index, "Max Temperature"] = response['main']['temp_max']
        weather_data.loc[index, "Humidity"] = response['main']['humidity']
        weather_data.loc[index, "Cloudiness"] = response['clouds']['all']
        weather_data.loc[index, "Wind Speed"] = response['wind']['speed']
        weather_data.loc[index, "Country"] = response['sys']['country']
        weather_data.loc[index, "Date"] = response['dt']
                
    except (KeyError, IndexError): 
        print("City not found. Skipping....")
        
print(f"-----------------------------")
print(f"Data Retrieval Complete")      
print(f"-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jijiga
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | puttur
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | olafsvik
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | college
# Processing Record 8 of Set 1 | forio
# Processing Record 9 of Set 1 | keflavik
# Processing Record 10 of Set 1 | touros
# Processing Record 11 of Set 1 | saint-philippe
# Processing Record 12 of Set 1 | tiarei
# Processing Record 13 of Set 1 | gander
# Processing Record 14 of Set 1 | ornskoldsvik
# Processing Record 15 of Set 1 | attawapiskat
# City not found. Skipping....
# Processing Record 16 of Set 1 | isangel
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | umzimvubu
# City not found. Skipping....
# Processing Record 19 of Set 1 | santa isabel
# Processing Record 20 of Set 1 | raudeberg
# Processing Record 21 of Set 1 | sungaipenuh
# Processing Record 22 of Set 1 | saskylakh
# Processing Record 23 of Set 1 | saldanha
# Processing Record 24 of Set 1 | georgetown
# Processing Record 25 of Set 1 | chuy
# Processing Record 26 of Set 1 | andenes
# Processing Record 27 of Set 1 | poronaysk
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | belushya guba
# City not found. Skipping....
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | codrington
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | arraial do cabo
# Processing Record 37 of Set 1 | carnarvon
# Processing Record 38 of Set 1 | pevek
# Processing Record 39 of Set 1 | kudahuvadhoo
# Processing Record 40 of Set 1 | vaitape
# Processing Record 41 of Set 1 | rostovka
# Processing Record 42 of Set 1 | tari
# Processing Record 43 of Set 1 | omsukchan
# Processing Record 44 of Set 1 | san cristobal
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping....
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | japura
# Processing Record 49 of Set 1 | qobustan
# Processing Record 50 of Set 1 | vanimo
# Processing Record 51 of Set 1 | ushuaia
# Processing Record 52 of Set 1 | emba
# Processing Record 53 of Set 1 | hamilton
# Processing Record 54 of Set 1 | barrow
# Processing Record 55 of Set 1 | aswan
# Processing Record 56 of Set 1 | kodiak
# Processing Record 57 of Set 1 | basqal
# Processing Record 58 of Set 1 | baltay
# Processing Record 59 of Set 1 | verkhovazhye
# Processing Record 60 of Set 1 | hami
# Processing Record 61 of Set 1 | khatanga
# Processing Record 62 of Set 1 | ponta do sol
# Processing Record 63 of Set 1 | igarka
# Processing Record 64 of Set 1 | tumannyy
# City not found. Skipping....
# Processing Record 65 of Set 1 | asilah
# Processing Record 66 of Set 1 | hithadhoo
# Processing Record 67 of Set 1 | tamiahua
# Processing Record 68 of Set 1 | faanui
# Processing Record 69 of Set 1 | tasiilaq
# Processing Record 70 of Set 1 | warqla
# City not found. Skipping....
# Processing Record 71 of Set 1 | lebu
# Processing Record 72 of Set 1 | howard springs
# Processing Record 73 of Set 1 | kapaa
# Processing Record 74 of Set 1 | sisimiut
# Processing Record 75 of Set 1 | hasaki
# Processing Record 76 of Set 1 | east london
# Processing Record 77 of Set 1 | shizunai
# Processing Record 78 of Set 1 | mayo
# Processing Record 79 of Set 1 | vaini
# Processing Record 80 of Set 1 | qaanaaq
# Processing Record 81 of Set 1 | bonthe
# Processing Record 82 of Set 1 | tuktoyaktuk
# Processing Record 83 of Set 1 | mar del plata
# Processing Record 84 of Set 1 | doha
# Processing Record 85 of Set 1 | victoria
# Processing Record 86 of Set 1 | atuona
# Processing Record 87 of Set 1 | berbera
# Processing Record 88 of Set 1 | lannion
# Processing Record 89 of Set 1 | uruzgan
# Processing Record 90 of Set 1 | ilulissat
# Processing Record 91 of Set 1 | huaiyin
# Processing Record 92 of Set 1 | ayan
# Processing Record 93 of Set 1 | tank
# Processing Record 94 of Set 1 | la serena
# Processing Record 95 of Set 1 | yucca valley
# Processing Record 96 of Set 1 | pacifica
# Processing Record 97 of Set 1 | grand river south east
# City not found. Skipping....
# Processing Record 98 of Set 1 | vostok
# Processing Record 99 of Set 1 | caravelas
# Processing Record 100 of Set 1 | hobart
# Processing Record 101 of Set 1 | provideniya
# Processing Record 102 of Set 1 | barentsburg
# City not found. Skipping....
# Processing Record 103 of Set 1 | padang
# Processing Record 104 of Set 1 | yatou
# Processing Record 105 of Set 1 | bereznik
# Processing Record 106 of Set 1 | chicama
# Processing Record 107 of Set 1 | weston
# Processing Record 108 of Set 1 | mubi
# Processing Record 109 of Set 1 | dzaoudzi
# Processing Record 110 of Set 1 | araouane
# Processing Record 111 of Set 1 | teacapan
# Processing Record 112 of Set 1 | honiara
# Processing Record 113 of Set 1 | merauke
# Processing Record 114 of Set 1 | nikolskoye
# Processing Record 115 of Set 1 | kologriv
# Processing Record 116 of Set 1 | yarada
# Processing Record 117 of Set 1 | novikovo
# Processing Record 118 of Set 1 | mahibadhoo
# Processing Record 119 of Set 1 | angra
# City not found. Skipping....
# Processing Record 120 of Set 1 | amahai
# Processing Record 121 of Set 1 | nuevo progreso
# Processing Record 122 of Set 1 | tsihombe
# City not found. Skipping....
# Processing Record 123 of Set 1 | bria
# Processing Record 124 of Set 1 | tres lagoas
# Processing Record 125 of Set 1 | ilhabela
# Processing Record 126 of Set 1 | iqaluit
# Processing Record 127 of Set 1 | bengkulu
# Processing Record 128 of Set 1 | porto nacional
# Processing Record 129 of Set 1 | gorontalo
# Processing Record 130 of Set 1 | nishihara
# Processing Record 131 of Set 1 | buzmeyin
# Processing Record 132 of Set 1 | burley
# Processing Record 133 of Set 1 | burica
# City not found. Skipping....
# Processing Record 134 of Set 1 | yulara
# Processing Record 135 of Set 1 | sistranda
# Processing Record 136 of Set 1 | harnosand
# Processing Record 137 of Set 1 | new norfolk
# Processing Record 138 of Set 1 | oranjemund
# Processing Record 139 of Set 1 | tuscaloosa
# Processing Record 140 of Set 1 | rawson
# Processing Record 141 of Set 1 | beloha
# Processing Record 142 of Set 1 | norman wells
# Processing Record 143 of Set 1 | sao filipe
# Processing Record 144 of Set 1 | castro
# Processing Record 145 of Set 1 | alihe
# Processing Record 146 of Set 1 | tongliao
# Processing Record 147 of Set 1 | rabo de peixe
# Processing Record 148 of Set 1 | uvalde
# Processing Record 149 of Set 1 | illoqqortoormiut
# City not found. Skipping....
# Processing Record 150 of Set 1 | aranos
# Processing Record 151 of Set 1 | mitu
# Processing Record 152 of Set 1 | cayenne
# Processing Record 153 of Set 1 | reftinskiy
# Processing Record 154 of Set 1 | avarua
# Processing Record 155 of Set 1 | sergiyevsk
# Processing Record 156 of Set 1 | torbay
# Processing Record 157 of Set 1 | kahului
# Processing Record 158 of Set 1 | cockburn town
# Processing Record 159 of Set 1 | tiksi
# Processing Record 160 of Set 1 | salinas
# Processing Record 161 of Set 1 | palabuhanratu
# City not found. Skipping....
# Processing Record 162 of Set 1 | waiouru
# Processing Record 163 of Set 1 | clyde river
# Processing Record 164 of Set 1 | cowra
# Processing Record 165 of Set 1 | amderma
# City not found. Skipping....
# Processing Record 166 of Set 1 | deyang
# Processing Record 167 of Set 1 | dingle
# Processing Record 168 of Set 1 | buchanan
# Processing Record 169 of Set 1 | vao
# Processing Record 170 of Set 1 | broome
# Processing Record 171 of Set 1 | mogadishu
# Processing Record 172 of Set 1 | dikson
# Processing Record 173 of Set 1 | yellowknife
# Processing Record 174 of Set 1 | ribeira grande
# Processing Record 175 of Set 1 | roma
# Processing Record 176 of Set 1 | sotnikovskoye
# Processing Record 177 of Set 1 | severo-kurilsk
# Processing Record 178 of Set 1 | kieta
# Processing Record 179 of Set 1 | port elizabeth
# Processing Record 180 of Set 1 | balikpapan
# Processing Record 181 of Set 1 | yelnya
# Processing Record 182 of Set 1 | acapulco
# Processing Record 183 of Set 1 | namibe
# Processing Record 184 of Set 1 | charters towers
# Processing Record 185 of Set 1 | chake chake
# Processing Record 186 of Set 1 | hihifo
# City not found. Skipping....
# Processing Record 187 of Set 1 | ponta delgada
# Processing Record 188 of Set 1 | baoding
# Processing Record 189 of Set 1 | kirakira
# Processing Record 190 of Set 1 | souillac
# Processing Record 191 of Set 1 | palmares
# Processing Record 192 of Set 1 | katima mulilo
# Processing Record 193 of Set 1 | hudson bay
# Processing Record 194 of Set 1 | horta
# Processing Record 195 of Set 1 | matara
# Processing Record 196 of Set 1 | kanniyakumari
# Processing Record 197 of Set 1 | luderitz
# Processing Record 198 of Set 1 | ormara
# Processing Record 199 of Set 1 | manaure
# Processing Record 200 of Set 1 | guerrero negro
# Processing Record 201 of Set 1 | villa vazquez
# City not found. Skipping....
# Processing Record 202 of Set 1 | pochutla
# Processing Record 203 of Set 1 | sitka
# Processing Record 204 of Set 1 | fort-shevchenko
# Processing Record 205 of Set 1 | krasnaya gora
# Processing Record 206 of Set 1 | la ronge
# Processing Record 207 of Set 1 | saint-augustin
# Processing Record 208 of Set 1 | labrea
# Processing Record 209 of Set 1 | shakawe
# Processing Record 210 of Set 1 | linares
# Processing Record 211 of Set 1 | kijang
# Processing Record 212 of Set 1 | aklavik
# Processing Record 213 of Set 1 | sola
# Processing Record 214 of Set 1 | hobyo
# Processing Record 215 of Set 1 | port hardy
# Processing Record 216 of Set 1 | camacha
# Processing Record 217 of Set 1 | saint george
# Processing Record 218 of Set 1 | kuche
# City not found. Skipping....
# Processing Record 219 of Set 1 | waw
# Processing Record 220 of Set 1 | abeche
# Processing Record 221 of Set 1 | tabiauea
# City not found. Skipping....
# Processing Record 222 of Set 1 | evensk
# Processing Record 223 of Set 1 | ancud
# Processing Record 224 of Set 1 | broken hill
# Processing Record 225 of Set 1 | coihaique
# Processing Record 226 of Set 1 | necochea
# Processing Record 227 of Set 1 | bima
# Processing Record 228 of Set 1 | lompoc
# Processing Record 229 of Set 1 | butaritari
# Processing Record 230 of Set 1 | ugoofaaru
# Processing Record 231 of Set 1 | belle fourche
# Processing Record 232 of Set 1 | tigil
# Processing Record 233 of Set 1 | qaqortoq
# Processing Record 234 of Set 1 | kindu
# Processing Record 235 of Set 1 | toftir
# City not found. Skipping....
# Processing Record 236 of Set 1 | havelock
# Processing Record 237 of Set 1 | gallup
# Processing Record 238 of Set 1 | katherine
# Processing Record 239 of Set 1 | neiafu
# Processing Record 240 of Set 1 | zyryanka
# Processing Record 241 of Set 1 | lasa
# Processing Record 242 of Set 1 | shambu
# Processing Record 243 of Set 1 | san quintin
# Processing Record 244 of Set 1 | goderich
# Processing Record 245 of Set 1 | nemuro
# Processing Record 246 of Set 1 | barabash
# Processing Record 247 of Set 1 | hilo
# Processing Record 248 of Set 1 | livno
# Processing Record 249 of Set 1 | mount pleasant
# Processing Record 250 of Set 1 | birao
# Processing Record 251 of Set 1 | tual
# Processing Record 252 of Set 1 | bethel
# Processing Record 253 of Set 1 | taltal
# Processing Record 254 of Set 1 | illapel
# Processing Record 255 of Set 1 | ust-kut
# Processing Record 256 of Set 1 | nanortalik
# Processing Record 257 of Set 1 | gizo
# Processing Record 258 of Set 1 | auki
# Processing Record 259 of Set 1 | vardo
# Processing Record 260 of Set 1 | port blair
# Processing Record 261 of Set 1 | lorengau
# Processing Record 262 of Set 1 | alyangula
# Processing Record 263 of Set 1 | temaraia
# City not found. Skipping....
# Processing Record 264 of Set 1 | ketchikan
# Processing Record 265 of Set 1 | belmonte
# Processing Record 266 of Set 1 | seoul
# Processing Record 267 of Set 1 | salta
# Processing Record 268 of Set 1 | correntina
# Processing Record 269 of Set 1 | laguna
# Processing Record 270 of Set 1 | cabo san lucas
# Processing Record 271 of Set 1 | kaitangata
# Processing Record 272 of Set 1 | wigston
# Processing Record 273 of Set 1 | fortuna
# Processing Record 274 of Set 1 | henties bay
# Processing Record 275 of Set 1 | port lincoln
# Processing Record 276 of Set 1 | mrirt
# City not found. Skipping....
# Processing Record 277 of Set 1 | catamarca
# Processing Record 278 of Set 1 | chebsara
# Processing Record 279 of Set 1 | mach
# Processing Record 280 of Set 1 | ambalavao
# Processing Record 281 of Set 1 | gobabis
# Processing Record 282 of Set 1 | tombouctou
# Processing Record 283 of Set 1 | longyearbyen
# Processing Record 284 of Set 1 | platanos
# Processing Record 285 of Set 1 | puri
# Processing Record 286 of Set 1 | malindi
# Processing Record 287 of Set 1 | chokurdakh
# Processing Record 288 of Set 1 | bathsheba
# Processing Record 289 of Set 1 | halalo
# City not found. Skipping....
# Processing Record 290 of Set 1 | dudinka
# Processing Record 291 of Set 1 | corn island
# Processing Record 292 of Set 1 | toliary
# City not found. Skipping....
# Processing Record 293 of Set 1 | leh
# Processing Record 294 of Set 1 | prieska
# Processing Record 295 of Set 1 | los llanos de aridane
# Processing Record 296 of Set 1 | dwarka
# Processing Record 297 of Set 1 | mantua
# Processing Record 298 of Set 1 | jalu
# Processing Record 299 of Set 1 | paita
# Processing Record 300 of Set 1 | kamenskoye
# City not found. Skipping....
# Processing Record 301 of Set 1 | upernavik
# Processing Record 302 of Set 1 | cidreira
# Processing Record 303 of Set 1 | samusu
# City not found. Skipping....
# Processing Record 304 of Set 1 | berlevag
# Processing Record 305 of Set 1 | san patricio
# Processing Record 306 of Set 1 | fujin
# Processing Record 307 of Set 1 | verkhnyaya inta
# Processing Record 308 of Set 1 | puerto escondido
# Processing Record 309 of Set 1 | mahebourg
# Processing Record 310 of Set 1 | avera
# Processing Record 311 of Set 1 | jinka
# Processing Record 312 of Set 1 | najran
# Processing Record 313 of Set 1 | haibowan
# City not found. Skipping....
# Processing Record 314 of Set 1 | churapcha
# Processing Record 315 of Set 1 | shache
# Processing Record 316 of Set 1 | thompson
# Processing Record 317 of Set 1 | puerto baquerizo moreno
# Processing Record 318 of Set 1 | wagga wagga
# Processing Record 319 of Set 1 | panguipulli
# Processing Record 320 of Set 1 | pandan
# Processing Record 321 of Set 1 | statesville
# Processing Record 322 of Set 1 | aptos
# Processing Record 323 of Set 1 | lavrentiya
# Processing Record 324 of Set 1 | ghorawal
# Processing Record 325 of Set 1 | nalut
# Processing Record 326 of Set 1 | oshakati
# Processing Record 327 of Set 1 | talnakh
# Processing Record 328 of Set 1 | komsomolskiy
# Processing Record 329 of Set 1 | barao de melgaco
# Processing Record 330 of Set 1 | lagoa
# Processing Record 331 of Set 1 | ust-kuyga
# Processing Record 332 of Set 1 | poum
# Processing Record 333 of Set 1 | antofagasta
# Processing Record 334 of Set 1 | langres
# Processing Record 335 of Set 1 | borlange
# City not found. Skipping....
# Processing Record 336 of Set 1 | nago
# Processing Record 337 of Set 1 | kaseda
# Processing Record 338 of Set 1 | urumqi
# Processing Record 339 of Set 1 | huilong
# Processing Record 340 of Set 1 | sao joao da barra
# Processing Record 341 of Set 1 | dobryanka
# Processing Record 342 of Set 1 | lashio
# Processing Record 343 of Set 1 | montes altos
# Processing Record 344 of Set 1 | asau
# Processing Record 345 of Set 1 | sinnamary
# Processing Record 346 of Set 1 | balykshi
# City not found. Skipping....
# Processing Record 347 of Set 1 | amuntai
# Processing Record 348 of Set 1 | san julian
# Processing Record 349 of Set 1 | fairbanks
# Processing Record 350 of Set 1 | narsaq
# Processing Record 351 of Set 1 | langarud
# Processing Record 352 of Set 1 | zhigansk
# Processing Record 353 of Set 1 | adrar
# Processing Record 354 of Set 1 | koumac
# Processing Record 355 of Set 1 | nantucket
# Processing Record 356 of Set 1 | pangnirtung
# Processing Record 357 of Set 1 | comodoro rivadavia
# Processing Record 358 of Set 1 | vysotskoye
# Processing Record 359 of Set 1 | porto novo
# Processing Record 360 of Set 1 | kruisfontein
# Processing Record 361 of Set 1 | bluefield
# Processing Record 362 of Set 1 | airai
# Processing Record 363 of Set 1 | katsuura
# Processing Record 364 of Set 1 | dunedin
# Processing Record 365 of Set 1 | riyadh
# Processing Record 366 of Set 1 | pasni
# Processing Record 367 of Set 1 | leningradskiy
# Processing Record 368 of Set 1 | rohtak
# Processing Record 369 of Set 1 | craig
# Processing Record 370 of Set 1 | sorland
# Processing Record 371 of Set 1 | hofn
# Processing Record 372 of Set 1 | atar
# Processing Record 373 of Set 1 | waterford
# Processing Record 374 of Set 1 | hay river
# Processing Record 375 of Set 1 | boksitogorsk
# Processing Record 376 of Set 1 | kununurra
# Processing Record 377 of Set 1 | jiddah
# City not found. Skipping....
# Processing Record 378 of Set 1 | mehamn
# Processing Record 379 of Set 1 | karkaralinsk
# City not found. Skipping....
# Processing Record 380 of Set 1 | umm jarr
# City not found. Skipping....
# Processing Record 381 of Set 1 | arrifes
# Processing Record 382 of Set 1 | fort nelson
# Processing Record 383 of Set 1 | alofi
# Processing Record 384 of Set 1 | adwa
# Processing Record 385 of Set 1 | sur
# Processing Record 386 of Set 1 | oussouye
# Processing Record 387 of Set 1 | shelburne
# Processing Record 388 of Set 1 | mabay
# Processing Record 389 of Set 1 | danilov
# Processing Record 390 of Set 1 | vila velha
# Processing Record 391 of Set 1 | mangrul pir
# Processing Record 392 of Set 1 | wajid
# Processing Record 393 of Set 1 | havoysund
# Processing Record 394 of Set 1 | ryotsu
# Processing Record 395 of Set 1 | buin
# Processing Record 396 of Set 1 | la romana
# Processing Record 397 of Set 1 | tefe
# Processing Record 398 of Set 1 | fukue
# Processing Record 399 of Set 1 | otradnoye
# Processing Record 400 of Set 1 | bahia honda
# Processing Record 401 of Set 1 | nanyang
# Processing Record 402 of Set 1 | deputatskiy
# Processing Record 403 of Set 1 | tuatapere
# Processing Record 404 of Set 1 | tevriz
# Processing Record 405 of Set 1 | tautira
# Processing Record 406 of Set 1 | la rochelle
# Processing Record 407 of Set 1 | progreso
# Processing Record 408 of Set 1 | bambanglipuro
# Processing Record 409 of Set 1 | nizhneyansk
# City not found. Skipping....
# Processing Record 410 of Set 1 | karaul
# City not found. Skipping....
# Processing Record 411 of Set 1 | mys shmidta
# City not found. Skipping....
# Processing Record 412 of Set 1 | waipawa
# Processing Record 413 of Set 1 | karamay
# City not found. Skipping....
# Processing Record 414 of Set 1 | baboua
# City not found. Skipping....
# Processing Record 415 of Set 1 | villamontes
# Processing Record 416 of Set 1 | alfena
# Processing Record 417 of Set 1 | bulgan
# Processing Record 418 of Set 1 | isilkul
# Processing Record 419 of Set 1 | raga
# Processing Record 420 of Set 1 | zaysan
# Processing Record 421 of Set 1 | den helder
# Processing Record 422 of Set 1 | dickinson
# Processing Record 423 of Set 1 | grindavik
# Processing Record 424 of Set 1 | bambous virieux
# Processing Record 425 of Set 1 | constitucion
# Processing Record 426 of Set 1 | galveston
# Processing Record 427 of Set 1 | ahuimanu
# Processing Record 428 of Set 1 | rio grande
# Processing Record 429 of Set 1 | yerbogachen
# Processing Record 430 of Set 1 | sobrance
# Processing Record 431 of Set 1 | sobolevo
# Processing Record 432 of Set 1 | alta floresta
# Processing Record 433 of Set 1 | kenai
# Processing Record 434 of Set 1 | nelson bay
# Processing Record 435 of Set 1 | dakar
# Processing Record 436 of Set 1 | mildura
# Processing Record 437 of Set 1 | bilma
# Processing Record 438 of Set 1 | smithers
# Processing Record 439 of Set 1 | celestun
# Processing Record 440 of Set 1 | quatre cocos
# Processing Record 441 of Set 1 | bam
# Processing Record 442 of Set 1 | saint-joseph
# Processing Record 443 of Set 1 | anadyr
# Processing Record 444 of Set 1 | minden
# Processing Record 445 of Set 1 | mamlyutka
# Processing Record 446 of Set 1 | kayes
# Processing Record 447 of Set 1 | teya
# Processing Record 448 of Set 1 | la estancia
# Processing Record 449 of Set 1 | half moon bay
# Processing Record 450 of Set 1 | enshi
# Processing Record 451 of Set 1 | magnolia
# Processing Record 452 of Set 1 | khipro
# Processing Record 453 of Set 1 | alvdal
# Processing Record 454 of Set 1 | varska
# City not found. Skipping....
# Processing Record 455 of Set 1 | somerset east
# Processing Record 456 of Set 1 | jiuquan
# Processing Record 457 of Set 1 | chardara
# Processing Record 458 of Set 1 | nyirkarasz
# Processing Record 459 of Set 1 | svetlaya
# Processing Record 460 of Set 1 | hays
# Processing Record 461 of Set 1 | jacareacanga
# Processing Record 462 of Set 1 | sept-iles
# Processing Record 463 of Set 1 | yar-sale
# Processing Record 464 of Set 1 | geraldton
# Processing Record 465 of Set 1 | lobito
# Processing Record 466 of Set 1 | banfora
# Processing Record 467 of Set 1 | wasilla
# Processing Record 468 of Set 1 | margate
# Processing Record 469 of Set 1 | tabou
# Processing Record 470 of Set 1 | floro
# Processing Record 471 of Set 1 | palma di montechiaro
# Processing Record 472 of Set 1 | tura
# Processing Record 473 of Set 1 | hirara
# Processing Record 474 of Set 1 | taburi
# City not found. Skipping....
# Processing Record 475 of Set 1 | kargasok
# Processing Record 476 of Set 1 | mutsu
# Processing Record 477 of Set 1 | changli
# Processing Record 478 of Set 1 | kavieng
# Processing Record 479 of Set 1 | marsh harbour
# Processing Record 480 of Set 1 | vila franca do campo
# Processing Record 481 of Set 1 | wanning
# Processing Record 482 of Set 1 | juneau
# Processing Record 483 of Set 1 | virginia beach
# Processing Record 484 of Set 1 | marsa matruh
# Processing Record 485 of Set 1 | palpa
# Processing Record 486 of Set 1 | taksimo
# Processing Record 487 of Set 1 | saleaula
# City not found. Skipping....
# Processing Record 488 of Set 1 | enkoping
# Processing Record 489 of Set 1 | maksatikha
# Processing Record 490 of Set 1 | carpinteria
# Processing Record 491 of Set 1 | sentyabrskiy
# City not found. Skipping....
# Processing Record 492 of Set 1 | shchelyayur
# City not found. Skipping....
# Processing Record 493 of Set 1 | el bordo
# Processing Record 494 of Set 1 | central point
# Processing Record 495 of Set 1 | blagoveshchensk
# Processing Record 496 of Set 1 | sawakin
# Processing Record 497 of Set 1 | mount gambier
# Processing Record 498 of Set 1 | phuket
# Processing Record 499 of Set 1 | asosa
# Processing Record 500 of Set 1 | baykit
# Processing Record 501 of Set 1 | elizabeth city
# Processing Record 502 of Set 1 | darab
# Processing Record 503 of Set 1 | orchard homes
# Processing Record 504 of Set 1 | salinopolis
# Processing Record 505 of Set 1 | batouri
# Processing Record 506 of Set 1 | mandera
# Processing Record 507 of Set 1 | launceston
# Processing Record 508 of Set 1 | gaoual
# Processing Record 509 of Set 1 | husavik
# Processing Record 510 of Set 1 | brae
# Processing Record 511 of Set 1 | kusye-aleksandrovskiy
# City not found. Skipping....
# Processing Record 512 of Set 1 | de-kastri
# Processing Record 513 of Set 1 | matay
# Processing Record 514 of Set 1 | kosa
# Processing Record 515 of Set 1 | esperance
# Processing Record 516 of Set 1 | camocim
# Processing Record 517 of Set 1 | tocopilla
# Processing Record 518 of Set 1 | thunder bay
# Processing Record 519 of Set 1 | malim
# Processing Record 520 of Set 1 | sapao
# City not found. Skipping....
# Processing Record 521 of Set 1 | juifang
# City not found. Skipping....
# Processing Record 522 of Set 1 | carnot
# Processing Record 523 of Set 1 | pontes e lacerda
# Processing Record 524 of Set 1 | peruibe
# Processing Record 525 of Set 1 | gushikawa
# Processing Record 526 of Set 1 | saint-georges
# Processing Record 527 of Set 1 | killybegs
# Processing Record 528 of Set 1 | pisco
# Processing Record 529 of Set 1 | orlik
# Processing Record 530 of Set 1 | atasu
# Processing Record 531 of Set 1 | roald
# Processing Record 532 of Set 1 | richards bay
# Processing Record 533 of Set 1 | flinders
# Processing Record 534 of Set 1 | bela
# Processing Record 535 of Set 1 | takoradi
# Processing Record 536 of Set 1 | klyuchi
# Processing Record 537 of Set 1 | mitchell
# Processing Record 538 of Set 1 | boa vista
# Processing Record 539 of Set 1 | olinda
# Processing Record 540 of Set 1 | luganville
# Processing Record 541 of Set 1 | nguiu
# City not found. Skipping....
# Processing Record 542 of Set 1 | buritizeiro
# Processing Record 543 of Set 1 | pangkalanbuun
# Processing Record 544 of Set 1 | tuensang
# Processing Record 545 of Set 1 | marawi
# Processing Record 546 of Set 1 | swellendam
# Processing Record 547 of Set 1 | hayrabolu
# Processing Record 548 of Set 1 | makakilo city
# Processing Record 549 of Set 1 | naze
# Processing Record 550 of Set 1 | tuban
# Processing Record 551 of Set 1 | biltine
# Processing Record 552 of Set 1 | nyurba
# Processing Record 553 of Set 1 | bontang
# Processing Record 554 of Set 1 | mbandaka
# Processing Record 555 of Set 1 | jieshi
# Processing Record 556 of Set 1 | australind
# Processing Record 557 of Set 1 | kerman
# Processing Record 558 of Set 1 | klaksvik
# Processing Record 559 of Set 1 | okha
# Processing Record 560 of Set 1 | verkhnevilyuysk
# Processing Record 561 of Set 1 | umm kaddadah
# Processing Record 562 of Set 1 | samalaeulu
# City not found. Skipping....
# Processing Record 563 of Set 1 | bac lieu
# Processing Record 564 of Set 1 | rafsanjan
# Processing Record 565 of Set 1 | ardakan
# Processing Record 566 of Set 1 | dong xoai
# Processing Record 567 of Set 1 | upington
# Processing Record 568 of Set 1 | ostrovnoy
# Processing Record 569 of Set 1 | ksenyevka
# City not found. Skipping....
# Processing Record 570 of Set 1 | buraydah
# Processing Record 571 of Set 1 | durban
# Processing Record 572 of Set 1 | bayburt
# Processing Record 573 of Set 1 | cody
# Processing Record 574 of Set 1 | sainte-suzanne
# Processing Record 575 of Set 1 | bonavista
# Processing Record 576 of Set 1 | pergamino
# Processing Record 577 of Set 1 | nanakuli
# Processing Record 578 of Set 1 | quetzaltepec
# City not found. Skipping....
# Processing Record 579 of Set 1 | macaboboni
# City not found. Skipping....
# Processing Record 580 of Set 1 | zhicheng
# Processing Record 581 of Set 1 | mopti
# Processing Record 582 of Set 1 | sosnovo-ozerskoye
# Processing Record 583 of Set 1 | samarai
# Processing Record 584 of Set 1 | gamba
# Processing Record 585 of Set 1 | tezu
# Processing Record 586 of Set 1 | te anau
# Processing Record 587 of Set 1 | mezen
# Processing Record 588 of Set 1 | mezhdurechensk
# Processing Record 589 of Set 1 | caimito
# Processing Record 590 of Set 1 | honningsvag
# Processing Record 591 of Set 1 | cascas
# Processing Record 592 of Set 1 | gumushane
# City not found. Skipping....
# Processing Record 593 of Set 1 | revda
# Processing Record 594 of Set 1 | trincomalee
# Processing Record 595 of Set 1 | mujiayingzi
# Processing Record 596 of Set 1 | prescott
# Processing Record 597 of Set 1 | taoudenni
# Processing Record 598 of Set 1 | vicuna
# Processing Record 599 of Set 1 | rudsar
# Processing Record 600 of Set 1 | west wendover
# Processing Record 601 of Set 1 | mineiros
# Processing Record 602 of Set 1 | itaporanga
# Processing Record 603 of Set 1 | cordoba
# Processing Record 604 of Set 1 | nuzvid
# Processing Record 605 of Set 1 | urusha
# Processing Record 606 of Set 1 | yenagoa
# Processing Record 607 of Set 1 | canutama
# Processing Record 608 of Set 1 | nikko
# Processing Record 609 of Set 1 | ostersund
# Processing Record 610 of Set 1 | grand gaube
# Processing Record 611 of Set 1 | loding
# Processing Record 612 of Set 1 | plettenberg bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
compression_opts = dict(method='zip',
                        archive_name='my_cities.csv')  
weather_data.to_csv('my_cities.zip', index=False,
          compression=compression_opts)

# %%
weather_data.count()
# Out:
# City               612
# Latitude           612
# Longitude          612
# Max Temperature    612
# Humidity           612
# Cloudiness         612
# Wind Speed         612
# Country            612
# Date               612
# dtype: int64

# %%
weather_data
# Out:
#                 City Latitude Longitude Max Temperature Humidity Cloudiness  \
# 0             jijiga     9.35      42.8           63.61       78         89
# 1             albany     42.6    -73.97           82.99       62         56
# 2             puttur    12.77     75.22            82.4       83         40
# 3        port alfred   -33.59     26.89           62.76       84          0
# 4           olafsvik    64.89    -23.71            49.8       71         60
# ..               ...      ...       ...             ...      ...        ...
# 607            nikko    36.75    139.62              73       84        100
# 608        ostersund    63.18     14.64            53.6       58         48
# 609      grand gaube   -20.01     57.66              64       76          3
# 610           loding     67.3     14.75            55.4       71         75
# 611  plettenberg bay   -34.05     23.37           59.67       79          0
#
#     Wind Speed Country        Date
# 0        12.57      ET  1595434430
# 1         3.83      US  1595433935
# 2         0.54      IN  1595434431
# 3         2.01      ZA  1595434281
# 4         7.96      IS  1595434169
# ..         ...     ...         ...
# 607       5.01      JP  1595434531
# 608      19.46      SE  1595434531
# 609          3      MU  1595434531
# 610      12.75      NO  1595434531
# 611       4.79      ZA  1595434532
#
# [612 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_data_humidity = weather_data.loc[weather_data["Humidity"] > 100]
weather_data_humidity
# Out:
# Empty DataFrame
# Columns: [City, Latitude, Longitude, Max Temperature, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv
#already exported above

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
weather_data.head()
# Out:
#           City Latitude Longitude Max Temperature Humidity Cloudiness  \
# 0       jijiga     9.35      42.8           63.61       78         89
# 1       albany     42.6    -73.97           82.99       62         56
# 2       puttur    12.77     75.22            82.4       83         40
# 3  port alfred   -33.59     26.89           62.76       84          0
# 4     olafsvik    64.89    -23.71            49.8       71         60
#
#   Wind Speed Country        Date
# 0      12.57      ET  1595434430
# 1       3.83      US  1595433935
# 2       0.54      IN  1595434431
# 3       2.01      ZA  1595434281
# 4       7.96      IS  1595434169

# %%
weather_data.dtypes
# Out:
# City               object
# Latitude           object
# Longitude          object
# Max Temperature    object
# Humidity           object
# Cloudiness         object
# Wind Speed         object
# Country            object
# Date               object
# dtype: object

# %%
weather_data["Latitude"] = pd.to_numeric(weather_data["Latitude"], errors='coerce')
weather_data["Max Temperature"] = pd.to_numeric(weather_data["Max Temperature"], errors='coerce')
weather_data["Humidity"] = pd.to_numeric(weather_data["Humidity"], errors='coerce')
weather_data["Cloudiness"] = pd.to_numeric(weather_data["Cloudiness"], errors='coerce')
weather_data["Wind Speed"] = pd.to_numeric(weather_data["Wind Speed"], errors='coerce')

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
scatter_one = plt.figure()
x_values = weather_data['Latitude']
y_values = weather_data['Max Temperature']
t = y_values
plt.scatter(x_values, y_values, c=t, cmap='viridis', edgecolors='black')
plt.title = ("City Latitude vs Max Temperature (7/20/2020)")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.savefig("C:\\Users\\me\\Desktop\\BBC\\COPY_but-ind-data-pt-06-2020-u-c\\Unit_06_Python_APIs\\Homework\\WeatherPy\\Images\\latitude_vs_temperature.png")
plt.show()

# %%
#Observation: the closer you get to the equator, the higher the temperature, with the
#PNG image for each scatter plot.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
scatter_two = plt.figure()
x_values = weather_data['Latitude']
y_values = weather_data['Humidity']
t = y_values
plt.scatter(x_values, y_values, c=t, cmap='viridis', edgecolors='black')
plt.title = ("City Latitude vs Humidity (7/20/2020)")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.savefig("C:\\Users\\me\\Desktop\\BBC\\COPY_but-ind-data-pt-06-2020-u-c\\Unit_06_Python_APIs\\Homework\\WeatherPy\\Images\\latitude_vs_humidity.png")
plt.show()

# %%
#Observation
#PNG image for each scatter plot.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
scatter_three = plt.figure()
x_values = weather_data['Latitude']
y_values = weather_data['Cloudiness']
t = y_values
plt.scatter(x_values, y_values, c=t, cmap='viridis', edgecolors='black')
plt.title = ("City Latitude vs Cloudiness (7/20/2020)")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.savefig("C:\\Users\\me\\Desktop\\BBC\\COPY_but-ind-data-pt-06-2020-u-c\\Unit_06_Python_APIs\\Homework\\WeatherPy\\Images\\latitude_vs_cloudiness.png")
plt.show()

# %%
#Observation
#PNG image for each scatter plot.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
scatter_four = plt.figure()
x_values = weather_data['Latitude']
y_values = weather_data['Wind Speed']
t = y_values
plt.scatter(x_values, y_values, c=t, cmap='viridis', edgecolors='black')
plt.title = ("City Latitude vs Wind Speed (7/20/2020)")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.savefig("C:\\Users\\me\\Desktop\\BBC\\COPY_but-ind-data-pt-06-2020-u-c\\Unit_06_Python_APIs\\Homework\\WeatherPy\\Images\\latitude_vs_wind_speed.png")
plt.show()

# %%
#Observation
#PNG image for each scatter plot.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
#Observations
#PNG image for each scatter plot

# %%
northern_hemisphere = weather_data.loc[(weather_data["Latitude"] >= 0)]
northern_hemisphere
# Out:
#           City  Latitude Longitude  Max Temperature  Humidity  Cloudiness  \
# 0       jijiga      9.35      42.8            63.61      78.0        89.0
# 1       albany     42.60    -73.97            82.99      62.0        56.0
# 2       puttur     12.77     75.22            82.40      83.0        40.0
# 4     olafsvik     64.89    -23.71            49.80      71.0        60.0
# 6      college     64.86    -147.8            51.80      87.0        90.0
# ..         ...       ...       ...              ...       ...         ...
# 604     urusha     54.05     122.9            62.08      55.0       100.0
# 605    yenagoa      4.92      6.26            79.07      84.0        98.0
# 607      nikko     36.75    139.62            73.00      84.0       100.0
# 608  ostersund     63.18     14.64            53.60      58.0        48.0
# 610     loding     67.30     14.75            55.40      71.0        75.0
#
#      Wind Speed Country        Date
# 0         12.57      ET  1595434430
# 1          3.83      US  1595433935
# 2          0.54      IN  1595434431
# 4          7.96      IS  1595434169
# 6          2.15      US  1595434207
# ..          ...     ...         ...
# 604        4.18      RU  1595434530
# 605        9.46      NG  1595434530
# 607        5.01      JP  1595434531
# 608       19.46      SE  1595434531
# 610       12.75      NO  1595434531
#
# [389 rows x 9 columns]

# %%
southern_hemisphere = weather_data.loc[(weather_data["Latitude"] < 0)]
southern_hemisphere
# Out:
#                 City  Latitude Longitude  Max Temperature  Humidity  \
# 3        port alfred    -33.59     26.89            62.76      84.0
# 5            mataura    -46.19    168.86            39.00      83.0
# 9             touros     -5.20    -35.46            84.20      58.0
# 10    saint-philippe    -21.36     55.77            68.00      64.0
# 11            tiarei    -17.53   -149.33            71.60      83.0
# ..               ...       ...       ...              ...       ...
# 601       itaporanga     -7.30    -38.15            90.91      24.0
# 602          cordoba    -31.41    -64.18            57.00      71.0
# 606         canutama     -6.53    -64.38            95.97      35.0
# 609      grand gaube    -20.01     57.66            64.00      76.0
# 611  plettenberg bay    -34.05     23.37            59.67      79.0
#
#      Cloudiness  Wind Speed Country        Date
# 3           0.0        2.01      ZA  1595434281
# 5          95.0        3.00      NZ  1595434140
# 9          75.0       11.41      BR  1595434207
# 10         90.0        6.93      RE  1595433931
# 11         75.0        3.36      PF  1595434432
# ..          ...         ...     ...         ...
# 601         0.0       10.71      BR  1595433967
# 602        75.0        3.36      AR  1595434530
# 606        70.0        2.13      BR  1595434530
# 609         3.0        3.00      MU  1595434531
# 611         0.0        4.79      ZA  1595434532
#
# [173 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
scatter_five = plt.figure()
x_values = northern_hemisphere['Latitude']
y_values = northern_hemisphere['Max Temperature']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
t = x_values
plt.scatter(x_values, y_values, c=t, cmap='viridis', edgecolors='black')
plt.plot(x_values,regress_values,"r-") 
plt.title = ("City Latitude vs Max Temperature: Northern Hemisphere (7/20/2020)")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.savefig("C:\\Users\\me\\Desktop\\BBC\\COPY_but-ind-data-pt-06-2020-u-c\\Unit_06_Python_APIs\\Homework\\WeatherPy\\Images\\northern_latitude_vs_temperature.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
scatter_six = plt.figure()
x_values = southern_hemisphere['Latitude']
y_values = southern_hemisphere['Max Temperature']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
t = x_values
plt.scatter(x_values, y_values, c=t, cmap='viridis', edgecolors='black')
plt.plot(x_values,regress_values,"r-") 
plt.title = ("City Latitude vs Max Temperature: Northern Hemisphere (7/20/2020)")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.savefig("C:\\Users\\me\\Desktop\\BBC\\COPY_but-ind-data-pt-06-2020-u-c\\Unit_06_Python_APIs\\Homework\\WeatherPy\\Images\\southern_latitude_vs_temperature.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
scatter_seven = plt.figure()
x_values = northern_hemisphere['Latitude']
y_values = northern_hemisphere['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
t = x_values
plt.scatter(x_values, y_values, c=t, cmap='viridis', edgecolors='black')
plt.plot(x_values,regress_values,"r-") 
plt.title = ("City Latitude vs Humidity: Northern Hemisphere (7/20/2020)")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.savefig("C:\\Users\\me\\Desktop\\BBC\\COPY_but-ind-data-pt-06-2020-u-c\\Unit_06_Python_APIs\\Homework\\WeatherPy\\Images\\northern_latitude_vs_humidity.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
scatter_eight = plt.figure()
x_values = southern_hemisphere['Latitude']
y_values = southern_hemisphere['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
t = x_values
plt.scatter(x_values, y_values, c=t, cmap='viridis', edgecolors='black')
plt.plot(x_values,regress_values,"r-") 
plt.title = ("City Latitude vs Humidity: Northern Hemisphere (7/20/2020)")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.savefig("C:\\Users\\me\\Desktop\\BBC\\COPY_but-ind-data-pt-06-2020-u-c\\Unit_06_Python_APIs\\Homework\\WeatherPy\\Images\\southern_latitude_vs_humidity.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
scatter_nine = plt.figure()
x_values = northern_hemisphere['Latitude']
y_values = northern_hemisphere['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
t = x_values
plt.scatter(x_values, y_values, c=t, cmap='viridis', edgecolors='black')
plt.plot(x_values,regress_values,"r-") 
plt.title = ("City Latitude vs Cloudiness: Northern Hemisphere (7/20/2020)")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.savefig("C:\\Users\\me\\Desktop\\BBC\\COPY_but-ind-data-pt-06-2020-u-c\\Unit_06_Python_APIs\\Homework\\WeatherPy\\Images\\northern_latitude_vs_cloudiness.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
scatter_ten = plt.figure()
x_values = southern_hemisphere['Latitude']
y_values = southern_hemisphere['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
t = x_values
plt.scatter(x_values, y_values, c=t, cmap='viridis', edgecolors='black')
plt.plot(x_values,regress_values,"r-") 
plt.title = ("City Latitude vs Cloudiness: Northern Hemisphere (7/20/2020)")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.savefig("C:\\Users\\me\\Desktop\\BBC\\COPY_but-ind-data-pt-06-2020-u-c\\Unit_06_Python_APIs\\Homework\\WeatherPy\\Images\\southern_latitude_vs_cloudiness.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
scatter_eleven = plt.figure()
x_values = northern_hemisphere['Latitude']
y_values = northern_hemisphere['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
t = x_values
plt.scatter(x_values, y_values, c=t, cmap='viridis', edgecolors='black')
plt.plot(x_values,regress_values,"r-") 
plt.title = ("City Latitude vs Wind Speed: Northern Hemisphere (7/20/2020)")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.savefig("C:\\Users\\me\\Desktop\\BBC\\COPY_but-ind-data-pt-06-2020-u-c\\Unit_06_Python_APIs\\Homework\\WeatherPy\\Images\\northern_latitude_vs_wind_speed.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
scatter_twelve = plt.figure()
x_values = southern_hemisphere['Latitude']
y_values = southern_hemisphere['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
t = x_values
plt.scatter(x_values, y_values, c=t, cmap='viridis', edgecolors='black')
plt.plot(x_values,regress_values,"r-") 
plt.title = ("City Latitude vs Wind Speed: Northern Hemisphere (7/20/2020)")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.savefig("C:\\Users\\me\\Desktop\\BBC\\COPY_but-ind-data-pt-06-2020-u-c\\Unit_06_Python_APIs\\Homework\\WeatherPy\\Images\\southern_latitude_vs_wind_speed.png")
plt.show()
